# %%
from tkinter import *
from tkinter import ttk
import tkinter.messagebox


class Hospital:
    def __init__(self,root):
        self.root=root
        self.root.title("MARIUM HOSPITAL")
        self.root.geometry("1540x800+0+0")
        self.root.configure(background="lightblue")
       
        cmbDoctors=StringVar()
        cmbCategory=StringVar()
        cmbTimmings=StringVar()
        cmbGender=StringVar()
        cmbDays=StringVar()
        Ref=StringVar()
        cmbDoctorID=StringVar()


        DailyDose=StringVar()
        FurtherInformation=StringVar()
        PatientNumber=StringVar()
        PatientName=StringVar()
        Age=StringVar()
        PatientAddress=StringVar()
        PatientCard=StringVar()
        #==========================Function mdeclaration=============
           
        def iExit():
            iExit=tkinter.messagebox.askyesno("MARIUM HOSPITAL","Confirm if you want to exit")
            if iExit>0:
                root.destroy()
                return
        def iAppointment():
           
            self.txtAppointment.insert(END,"Patient Name:- \t\t" + PatientName.get() + "\n")
            self.txtAppointment.insert(END,"Doctor ID:- \t\t" + cmbDoctorID.get() + "\n")
            self.txtAppointment.insert(END,"Doctor Name:- \t\t" + cmbDoctors.get() + "\n")
            self.txtAppointment.insert(END,"Category:- \t\t" + cmbCategory.get() + "\n")
            self.txtAppointment.insert(END,"Day:- \t\t" + cmbDays.get() + "\n")
            self.txtAppointment.insert(END,"Timmings:- \t\t" + cmbTimmings.get() + "\n")
            self.txtAppointment.insert(END,"Gender:- \t\t" + cmbGender.get() + "\n")
            self.txtAppointment.insert(END,"Daily Dose:- \t\t" + DailyDose.get() + "\n")
            self.txtAppointment.insert(END,"Further Information:- \t\t" + FurtherInformation.get() + "\n")
            self.txtAppointment.insert(END,"Patient Address: \t\t" + PatientAddress.get() + "\n")
            self.txtAppointment.insert(END,"Patient Card: \t\t" + PatientCard.get() + "\n")
            self.txtAppointment.insert(END,"\t\tFEES = 50 (for slip)\t\t\t")
            self.txtAppointment.insert(END,"\tKINDLY BRING THIS SLIP PRINTOUT ON THE APPOINTMENT DAY\t")
           
            return
           

        def iPrintSlip():
            iPrintSlip=tkinter.messagebox.askyesno("MARIUM HOSPITAL","Set up your printer to print slip!!")
           
            return
       
       
        def iReset():
            iReset=tkinter.messagebox.askyesno("MARIUM HOSPITAL","Confirm!!!! you want to reset")
            if iReset<0:
                root.delete("0.1",END)
                return
            cmbDoctors.set("")
            self.cboDoctors.current(0)
            self.cboDays.current(0)
            cmbDays.set("")
            self.cboDays.current(0)
            cmbTimmings.set("")
            self.cboTimmings.current(0)
            DailyDose.set("")
            FurtherInformation.set("")
            cmbDoctorID.set("")
            self.cboDoctorID.current(0)
            PatientName.set("")
            Age.set("")
            PatientAddress.set("")      
            PatientCard.set("")
            self.cboPatientCard.current(0)
            self.txtAppointment.delete("1.0",END)
           
                                   
            return
       
       
        def iDelete():
            iDelete=tkinter.messagebox.askyesno("MARIUM HOSPITAL","Your Data  will be deleted!!")
            if iDelete<0:
                root.delete("1.0",END)
                return
            self.txtAppointment.delete("1.0",END)
           
                                   
            return
       
        def new_window():
            new_window=Toplevel(root)
            new_window.title("ONLINE APPOINTMENT BOOKING")
            new_window.configure(bg="light blue")
            lbl=Label(new_window,font=("times new roman",40,"bold"),text="ONLINE APPOINTMENT BOOKING",fg="dark blue",bg="light blue")
            lbl.pack()
            lbl=Label(new_window,font=("times new roman",25,"bold"),text="Doctor's Details",fg="dark blue",bg="light blue")
            lbl.pack()
            DataFrameLEFT=LabelFrame(new_window,bd=20,width=1350,height=800,padx=80,relief=RIDGE,font=("Times new roman",16,"bold"),text="DETAILS")
            DataFrameLEFT.pack()
           
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Doctor Names",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=0,column=0,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.Nashra uzair",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=0,sticky=W)
     
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.Erum Usman",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=0,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.fahad shaikh",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=0,sticky=W)
     
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.Bushra Moin",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=0,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.Hamza Sultan",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=0,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dr.Ammar Ahmad",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=0,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Dr.ID",padx=5,pady=4,height=3)
            self.lblFurtherInfo.grid(row=0,column=2,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="415",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=2,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="231",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=2,sticky=W)
       
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="222",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=2,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="435",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=2,sticky=W)
       
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="140",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=2,sticky=W)
       
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="210",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=2,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Speciality",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=0,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Radiologist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Dentist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Cardiologist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Child Specialist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=3,sticky=W)
             
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Pshycologist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Physiotherapist",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=3,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Timmings",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=0,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="10AM TO 12PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=4,sticky=W)
             
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="12PM TO 3PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="3PM TO 5PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="5PM TO 8PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="8PM TO 10:45PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="12AM TO 3PM",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=4,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Fees",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=0,column=5,sticky=W)
           
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="400pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=5,sticky=W)
         
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="750pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=5,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="500pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=5,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="350pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=5,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="400pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=5,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="250pkr",padx=2,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=5,sticky=W)
       
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("times new roman",12,"bold"),text="Room",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=0,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room 3",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=1,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room 2",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=2,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room 6",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=3,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room 4",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=4,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room 7",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=5,column=6,sticky=W)
       
            self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12),text="Room14",padx=5,pady=2,height=3)
            self.lblFurtherInfo.grid(row=6,column=6,sticky=W)
           
            btn2=Button(new_window,text="Exit",font=("Times new roman",22,"bold"),bg="darkblue",fg="white",width=250,height=4,bd=10,command=lambda: new_window.destroy())
            btn2.pack(side=BOTTOM)
           
       
        #==============================MAIN WINDOW Frame==========================================================================================
       
        MainFrame=Frame(self.root,background="lightblue")
        MainFrame.grid()
       
        TitleFrame=Frame( MainFrame,bd=10,width=1350,padx=40,bg="dark blue",relief=RIDGE)
        TitleFrame.pack(side=TOP)
       
        self.lblTitle=Label(TitleFrame,font=("times new roman",40,"bold"),text="ONLINE APPOINTMENT BOOKING",fg="purple",bg="white",padx=8)
        self.lblTitle.grid()
   
        ButtonFrame=Frame(MainFrame,bd=20,width=300,height=600,padx=40,relief=RIDGE)
        ButtonFrame.pack(side=LEFT)
       
        DataFrameLEFT=LabelFrame(MainFrame,bd=20,width=400,height=600,padx=50,relief=RIDGE,font=("Times new roman",12,"bold"),text="Patient Information")
        DataFrameLEFT.pack(side=LEFT)
       
        DataFrameRIGHT=LabelFrame(MainFrame,bd=20,width=450,height=500,padx=40,relief=RIDGE,font=("Times new roman",12,"bold"),text=" Appointment")
        DataFrameRIGHT.pack(side=RIGHT)
       
        #===============================ButtonFrame=============================
        self.btnAppointment=Button(ButtonFrame,text="Appointment",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=4,bd=10,command=iAppointment)
        self.btnAppointment.grid(row=0,column=0)
        self.btnPrintSlip=Button(ButtonFrame,text="Print Slip",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=3,bd=10,command=iPrintSlip)
        self.btnPrintSlip.grid(row=1,column=0)
        self.btnDelete=Button(ButtonFrame,text="Delete",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=3,bd=10,command=iDelete)
        self.btnDelete.grid(row=2,column=0)
        self.btnReset=Button(ButtonFrame,text="Reset",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=3,bd=10,command=iReset)
        self.btnReset.grid(row=3,column=0)
        self.btnExit=Button(ButtonFrame,text="Exit",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=3,bd=10,command=iExit)
        self.btnExit.grid(row=4,column=0)
        self.btnnew_window=Button(ButtonFrame,text="Details",font=("Times new roman",12,"bold"),bg="darkblue",fg="white",width=22,height=3,bd=10,command=new_window)
        self.btnnew_window.grid(row=5,column=0)
       
        #================================DataFrameLEFT================================
       
        self.lblDoctors=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Name Of Doctors:-",padx=2,height=2)
        self.lblDoctors.grid(row=0,column=0,sticky=W)
   
        self.cboDoctors=ttk.Combobox(DataFrameLEFT,textvariable=cmbDoctors,state="readonly",font=("times new roman",12,"bold"),width=25,height=15)
        self.cboDoctors["value"]=("Dr.fahad shaikh(222) ","Dr.Nashra Uzair(415) ","Dr.erum Usman(231) ","Dr.Bushra Moin(435) ","Dr.Hamza Sultan(140)","Dr.Ammar Ahmad(210)")
        self.cboDoctors.current(0)
        self.cboDoctors.grid(row=0,column=1)
       
        self.lblFurtherInfo=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Further Information:-",padx=2,pady=2,height=2)
        self.lblFurtherInfo.grid(row=11,column=0,sticky=W)
        self.txtFurtherInfo=Entry(DataFrameLEFT,font=("arial",12,"bold"),textvariable=FurtherInformation,width=25)
        self.txtFurtherInfo.grid(row=11,column=1)  
                                     
        self.lblRef=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Category:-",padx=2,pady=2,height=2)
        self.lblRef.grid(row=1,column=0,sticky=W)
       
        self.cboCategory=ttk.Combobox(DataFrameLEFT,textvariable=cmbCategory,state="readonly",font=("times new roman",12,"bold"),width=25)
        self.cboCategory["value"]=("Cardiologist","Radiologist","Child specialist","Dentist","Physiotherapist","psyclogist")
        self.cboCategory.current(0)
        self.cboCategory.grid(row=1,column=1)
       
        self.lblDays=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Day:-",padx=2,height=2)
        self.lblDays.grid(row=2,column=0,sticky=W)
   
        self.cboDays=ttk.Combobox(DataFrameLEFT,textvariable=cmbDays,state="readonly",font=("times new roman",12,"bold"),width=25)
        self.cboDays["value"]=("Monday","Tuesday","Wednesday","Thursday","Friday","Saturday")
        self.cboDays.current(0)
        self.cboDays.grid(row=2,column=1)
       
       
        self.lblRef=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Timmings:-",padx=2,pady=2,height=2)
        self.lblRef.grid(row=3,column=0,sticky=W)
       
        self.cboTimmings=ttk.Combobox(DataFrameLEFT,textvariable=cmbTimmings,state="readonly",font=("times new roman",12,"bold"),width=25)
        self.cboTimmings["value"]=("10AM TO 12PM","12PM TO 3PM","3PM TO 5PM","5PM TO 8PM","8:PM TO 10:45PM")
        self.cboTimmings.current(0)
        self.cboTimmings.grid(row=3,column=1)
                                     
        self.lblRef=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Gender:-",padx=2,pady=2,height=2)
        self.lblRef.grid(row=4,column=0,sticky=W)
       
        self.cboGender=ttk.Combobox(DataFrameLEFT,textvariable=cmbGender,state="readonly",font=("times new roman",12,"bold"),width=25)
        self.cboGender["value"]=("Male","Female")
        self.cboGender.current(0)
        self.cboGender.grid(row=4,column=1)
                                           
         
        self.lblDoctorID=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Doctor ID:-",padx=2,pady=2,height=2)
        self.lblDoctorID.grid(row=5,column=0,sticky=W)
       
        self.cboDoctorID=ttk.Combobox(DataFrameLEFT,textvariable=cmbDoctorID,state="readonly",font=("times new roman",12,"bold"),width=25,height=15)
        self.cboDoctorID["value"]=("222 ","415 ","231 ","435 ","140","210")
        self.cboDoctorID.current(0)
        self.cboDoctorID.grid(row=5,column=1)
       
         
        self.lblPatientCard=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Patient Card:-",padx=2,pady=2,height=2)
        self.lblPatientCard.grid(row=10,column=0,sticky=W)
                                     
        self.cboPatientCard=ttk.Combobox(DataFrameLEFT,textvariable=PatientCard,state="readonly",font=("times new roman",12,"bold"),width=25)
        self.cboPatientCard["value"]=("yes","No")
        self.cboPatientCard.current(0)
        self.cboPatientCard.grid(row=10,column=1)
                                     

        self.lblPatientName=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Patient Name:-",padx=2,pady=2,height=2)
        self.lblPatientName.grid(row=6,column=0,sticky=W)
        self.txtPatientName=Entry(DataFrameLEFT,font=("arial",12,"bold"),textvariable=PatientName,width=25)
        self.txtPatientName.grid(row=6,column=1)
       
       
        self.lblDailyDose=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Daily Dose:-",padx=2,pady=2,height=2)
        self.lblDailyDose.grid(row=9,column=0,sticky=W)
        self.txtDailyDose=Entry(DataFrameLEFT,font=("arial",12,"bold"),textvariable=DailyDose,width=25)
        self.txtDailyDose.grid(row=9,column=1)  
       
        self.lblAge=Label(DataFrameLEFT,font=("arial",12,"bold"),text="Age:-",padx=2,pady=2,height=2)
        self.lblAge.grid(row=8,column=0,sticky=W)
        self.txtAge=Entry(DataFrameLEFT,font=("arial",12,"bold"),textvariable=Age,width=25)
        self.txtAge.grid(row=8,column=1)
       
   
        self.lblPatientAddress=Label(DataFrameLEFT,font=("arial",12,"bold"),text="PatientAddress:-",padx=2,pady=2,height=2)
        self.lblPatientAddress.grid(row=7,column=0,sticky=W)
        self.txtPatientAddress=Entry(DataFrameLEFT,font=("arial",12,"bold"),textvariable=PatientAddress,width=25)
        self.txtPatientAddress.grid(row=7,column=1)
       
          #==============================DataFrameRIGHT==============================
       
        self.txtAppointment=Text(DataFrameRIGHT,font=("Times new roman",12,"bold"),width=45,height=29,padx=1,pady=2)        
        self.txtAppointment.grid(row=0,column=0)
       
   
if __name__=="__main__":
    root=Tk()
    application =Hospital (root)
    root.mainloop()
